# %%
# Imports 
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import seaborn as sns

# %%
starttups = pd.read_csv('./Linear_Regression_50_Startups.csv')
starttups.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %%
X = starttups['R&D Spend'].values
y = starttups['Profit'].values

# %%
X = X.reshape(-1, 1)

# %%
x_train, x_test, y_train, y_test = train_test_split(X, y, train_size =0.7, test_size=0.3, random_state = 100)

# %%
print(f"X_train shape {x_train.shape}")
print(f"y_train shape {y_train.shape}")
print(f"X_test shape {x_test.shape}")
print(f"y_test shape {y_test.shape}")
# Out:
# X_train shape (35, 1)
# y_train shape (35,)
# X_test shape (15, 1)
# y_test shape (15,)

# %%
plt.scatter(x_train, y_train, color='green')
plt.xlabel('R&D Spend')
plt.ylabel('Profit')
plt.title('Showing profit based on R&S spending')
plt.show()

# %%
lm = LinearRegression()
lm.fit(x_train, y_train)
y_predict = lm.predict(x_test)
print(f"Train accuracy {round(lm.score(x_train, y_train) * 100,2)} %")
print(f"Test accuracy {round(lm.score(x_test, y_test) * 100,2)} %")
lm.score
# Out:
# Train accuracy 96.0 %
# Test accuracy 91.81 %
# <bound method RegressorMixin.score of LinearRegression()>

# %%
plt.scatter(x_train, y_train, color='green')
plt.plot(x_test, y_predict)
plt.xlabel('R&D Spend')
plt.ylabel('Profit')
plt.title('Showing profit based on R&S spending')
plt.show()

# %%
sns.set()
plt.figure(figsize=(8, 5), dpi=300)
sns.regplot(x='R&D Spend', y='Profit', data=starttups)

# %%
plt.figure(figsize=(12, 8), dpi=300)
sns.regplot(x='Marketing Spend', y='Profit', data=starttups).set(title='Profit rise based on Marketing spend')
# Out:
# [Text(0.5, 1.0, 'Profit rise based on Marketing spend')]

# %%
sns.regplot(x='Administration', y='Profit', color='r', data=starttups, order=3).set(title='Profit based on administration spend')
# Out:
# [Text(0.5, 1.0, 'Profit based on administration spend')]
